# %%
# Create Sparksession 

import os
import pyspark

# os.environ["PYSPARK_PYTHON"]="/usr/bin/python3"
# os.environ["PYSPARK_DRIVER_PYTHON"]="/usr/bin/python3"
myConf=pyspark.SparkConf()
spark = pyspark.sql.SparkSession\
    .builder\
    .master("local")\
    .appName("myApp")\
    .config(conf=myConf)\
    .getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# /FileStore/tables/data/제주특별자치도_서귀포시_고령화비율및노령화지수현황_20200623.csv
agedRdd = spark.sparkContext\
    .textFile(os.path.join("/FileStore/tables/data","제주특별자치도_서귀포시_고령화비율및노령화지수현황_20200623.csv"), use_unicode=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
agedRdd.take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: [&#39;������,�������� �α���,65���̻� �α��� ,0~14�� �α���,���ȭ����,���ȭ����,�����ͱ�������&#39;,
#  &#39;2012,154057,25826,22861,16.76,112.97,2020-06-23&#39;,
#  &#39;2013,155641,26936,22393,17.31,120.29,2020-06-23&#39;,
#  &#39;2014,158512,27877,22058,17.59,126.38,2020-06-23&#39;,
#  &#39;2015,164519,28979,22362,17.61,129.59,2020-06-23&#39;]</div>

# %%
for i in agedRdd.take(5):
    print(i)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">������,�������� �α���,65���̻� �α��� ,0~14�� �α���,���ȭ����,���ȭ����,�����ͱ�������
# 2012,154057,25826,22861,16.76,112.97,2020-06-23
# 2013,155641,26936,22393,17.31,120.29,2020-06-23
# 2014,158512,27877,22058,17.59,126.38,2020-06-23
# 2015,164519,28979,22362,17.61,129.59,2020-06-23
# </div>

# %%
ageRddBin = spark.sparkContext.binaryFiles(os.path.join("/FileStore/tables/data","제주특별자치도_서귀포시_고령화비율및노령화지수현황_20200623.csv"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
_my = ageRddBin.map(lambda x :x[1].decode('euc-kr'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
_my.take(1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: [&#39;연도별,서귀포시 인구수,65세이상 인구수 ,0~14세 인구수,고령화비율,노령화지수,데이터기준일자\r\n2012,154057,25826,22861,16.76,112.97,2020-06-23\r\n2013,155641,26936,22393,17.31,120.29,2020-06-23\r\n2014,158512,27877,22058,17.59,126.38,2020-06-23\r\n2015,164519,28979,22362,17.61,129.59,2020-06-23\r\n2016,170932,30030,23044,17.57,130.32,2020-06-23\r\n2017,173302,30545,23300,17.63,131.09,2020-06-23\r\n2018,181245,32394,24013,17.87,134.9,2020-06-23\r\n2019,181584,33707,23707,18.56,142.18,2020-06-23\r\n2020,181059,34456,23579,19.03,146.13,2020-06-23\r\n&#39;]</div>

# %%
ageList = _my.map(lambda x: x.split()).take(3)
ageList[0][1]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: &#39;인구수,65세이상&#39;</div>

# %%
agedDf = spark\
            .read.option("charset", "euc-kr")\
            .option("header", "true")\
            .csv(os.path.join("/FileStore/tables/data","제주특별자치도_서귀포시_고령화비율및노령화지수현황_20200623.csv"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
agedDf.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+---------------+----------------+-------------+----------+----------+--------------+
# 연도별|서귀포시 인구수|65세이상 인구수 |0~14세 인구수|고령화비율|노령화지수|데이터기준일자|
# +------+---------------+----------------+-------------+----------+----------+--------------+
#   2012|         154057|           25826|        22861|     16.76|    112.97|    2020-06-23|
#   2013|         155641|           26936|        22393|     17.31|    120.29|    2020-06-23|
#   2014|         158512|           27877|        22058|     17.59|    126.38|    2020-06-23|
#   2015|         164519|           28979|        22362|     17.61|    129.59|    2020-06-23|
#   2016|         170932|           30030|        23044|     17.57|    130.32|    2020-06-23|
# +------+---------------+----------------+-------------+----------+----------+--------------+
# only showing top 5 rows
#
# </div>

# %%
import os
import pyspark

def doIt():
    print ("---------RESULT-----------")
    agedDf = spark\
                .read.option("charset", "euc-kr")\
                .option("header", "true")\
                .csv(os.path.join("/FileStore/tables/data","제주특별자치도_서귀포시_고령화비율및노령화지수현황_20200623.csv"))
    agedDf.show(5)

if __name__ == "__main__":
    os.environ["PYSPARK_PYTHON"]="/usr/bin/python3"
    os.environ["PYSPARK_DRIVER_PYTHON"]="/usr/bin/python3"
    myConf=pyspark.SparkConf()
    spark = pyspark.sql.SparkSession.builder\
        .master("local")\
        .appName("myApp")\
        .config(conf=myConf)\
        .getOrCreate()
    doIt()
    spark.stop()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# !spark-submit src/ds3_popCsvRead.py
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
