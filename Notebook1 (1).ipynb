# %%
popList = _my.map(lambda x: x.split()).take(3)
popList[0][0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[63]: &#39;행정기관,인구수(계),인구수(남),인구수(여),구성비(계),구성비(남),구성비(여),성비,세대수,세대당인구,관리기관명,관리부서명,부서전화번호,데이터기준일자&#39;</div>

# %%
popList = _my.map(lambda x: x.split()).take(3)
popList[0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[64]: [&#39;행정기관,인구수(계),인구수(남),인구수(여),구성비(계),구성비(남),구성비(여),성비,세대수,세대당인구,관리기관명,관리부서명,부서전화번호,데이터기준일자&#39;,
#  &#39;의정부1동&#39;,
#  &#39;,31515&#39;,
#  &#39;,16078&#39;,
#  &#39;,15437&#39;,
#  &#39;,6.85,3.49,3.35,104.15,19338&#39;,
#  &#39;,1.63,의정부시,시민봉사과,031-828-2466,2020-12-02&#39;,
#  &#39;의정부2동&#39;,
#  &#39;,31239&#39;,
#  &#39;,15480&#39;,
#  &#39;,15759&#39;,
#  &#39;,6.79,3.36,3.42,98.23,15879&#39;,
#  &#39;,1.97,의정부시,시민봉사과,031-828-2466,2020-12-02&#39;,
#  &#39;호원1동&#39;,
#  &#39;,36297&#39;,
#  &#39;,17703&#39;,
#  &#39;,18594&#39;,
#  &#39;,7.88,3.85,4.04,95.21,15619&#39;,
#  &#39;,2.32,의정부시,시민봉사과,031-828-2466,2020-12-02&#39;,
#  &#39;호원2동&#39;,
#  &#39;,35314&#39;,
#  &#39;,17124&#39;,
#  &#39;,18190&#39;,
#  &#39;,7.67,3.72,3.95,94.14,13598&#39;,
#  &#39;,2.6,의정부시,시민봉사과,031-828-2466,2020-12-02&#39;,
#  &#39;장암동&#39;,
#  &#39;,20728&#39;,
#  &#39;,9880&#39;,
#  &#39;,10848&#39;,
#  &#39;,4.5,2.15,2.36,91.08,8662&#39;,
#  &#39;,2.39,의정부시,시민봉사과,031-828-2466,2020-12-02&#39;,
#  &#39;신곡1동&#39;,
#  &#39;,44031&#39;,
#  &#39;,21676&#39;,
#  &#39;,22355&#39;,
#  &#39;,9.56,4.71,4.86,96.96,18091&#39;,
#  &#39;,2.43,의정부시,시민봉사과,031-828-2466,2020-12-02&#39;,
#  &#39;신곡2동&#39;,
#  &#39;,48111&#39;,
#  &#39;,23335&#39;,
#  &#39;,24776&#39;,
#  &#39;,10.45,5.07,5.38,94.18,18897&#39;,
#  &#39;,2.55,의정부시,시민봉사과,031-828-2466,2020-12-02&#39;,
#  &#39;송산1동&#39;,
#  &#39;,38065&#39;,
#  &#39;,18889&#39;,
#  &#39;,19176&#39;,
#  &#39;,8.27,4.1,4.17,98.5,16645&#39;,
#  &#39;,2.29,의정부시,시민봉사과,031-828-2466,2020-12-02&#39;,
#  &#39;송산2동&#39;,
#  &#39;,33903&#39;,
#  &#39;,16781&#39;,
#  &#39;,17122&#39;,
#  &#39;,7.36,3.64,3.72,98.01,13108&#39;,
#  &#39;,2.59,의정부시,시민봉사과,031-828-2466,2020-12-02&#39;,
#  &#39;송산3동&#39;,
#  &#39;,46547&#39;,
#  &#39;,22641&#39;,
#  &#39;,23906&#39;,
#  &#39;,10.11,4.92,5.19,94.71,17644&#39;,
#  &#39;,2.64,의정부시,시민봉사과,031-828-2466,2020-12-02&#39;,
#  &#39;자금동&#39;,
#  &#39;,27163&#39;,
#  &#39;,13284&#39;,
#  &#39;,13879&#39;,
#  &#39;,5.9,2.89,3.01,95.71,11724&#39;,
#  &#39;,2.32,의정부시,시민봉사과,031-828-2466,2020-12-02&#39;,
#  &#39;가능동&#39;,
#  &#39;,26129&#39;,
#  &#39;,13051&#39;,
#  &#39;,13078&#39;,
#  &#39;,5.68,2.83,2.84,99.79,12432&#39;,
#  &#39;,2.1,의정부시,시민봉사과,031-828-2466,2020-12-02&#39;,
#  &#39;흥선동&#39;,
#  &#39;,19151&#39;,
#  &#39;,9656&#39;,
#  &#39;,9495&#39;,
#  &#39;,4.16,2.1,2.06,101.7,9295&#39;,
#  &#39;,2.06,의정부시,시민봉사과,031-828-2466,2020-12-02&#39;,
#  &#39;녹양동&#39;,
#  &#39;,22197&#39;,
#  &#39;,11078&#39;,
#  &#39;,11119&#39;,
#  &#39;,4.82,2.41,2.42,99.63,9503&#39;,
#  &#39;,2.34,의정부시,시민봉사과,031-828-2466,2020-12-02&#39;]</div>

# %%
popList = _my.map(lambda x: x.split()).take(3)
popList[0][1]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[65]: &#39;의정부1동&#39;</div>

# %%
_my.take(1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[66]: [&#39;행정기관,인구수(계),인구수(남),인구수(여),구성비(계),구성비(남),구성비(여),성비,세대수,세대당인구,관리기관명,관리부서명,부서전화번호,데이터기준일자\r\n의정부1동       ,31515 ,16078 ,15437 ,6.85,3.49,3.35,104.15,19338 ,1.63,의정부시,시민봉사과,031-828-2466,2020-12-02\r\n의정부2동       ,31239 ,15480 ,15759 ,6.79,3.36,3.42,98.23,15879 ,1.97,의정부시,시민봉사과,031-828-2466,2020-12-02\r\n호원1동         ,36297 ,17703 ,18594 ,7.88,3.85,4.04,95.21,15619 ,2.32,의정부시,시민봉사과,031-828-2466,2020-12-02\r\n호원2동         ,35314 ,17124 ,18190 ,7.67,3.72,3.95,94.14,13598 ,2.6,의정부시,시민봉사과,031-828-2466,2020-12-02\r\n장암동          ,20728 ,9880 ,10848 ,4.5,2.15,2.36,91.08,8662 ,2.39,의정부시,시민봉사과,031-828-2466,2020-12-02\r\n신곡1동         ,44031 ,21676 ,22355 ,9.56,4.71,4.86,96.96,18091 ,2.43,의정부시,시민봉사과,031-828-2466,2020-12-02\r\n신곡2동         ,48111 ,23335 ,24776 ,10.45,5.07,5.38,94.18,18897 ,2.55,의정부시,시민봉사과,031-828-2466,2020-12-02\r\n송산1동         ,38065 ,18889 ,19176 ,8.27,4.1,4.17,98.5,16645 ,2.29,의정부시,시민봉사과,031-828-2466,2020-12-02\r\n송산2동         ,33903 ,16781 ,17122 ,7.36,3.64,3.72,98.01,13108 ,2.59,의정부시,시민봉사과,031-828-2466,2020-12-02\r\n송산3동         ,46547 ,22641 ,23906 ,10.11,4.92,5.19,94.71,17644 ,2.64,의정부시,시민봉사과,031-828-2466,2020-12-02\r\n자금동          ,27163 ,13284 ,13879 ,5.9,2.89,3.01,95.71,11724 ,2.32,의정부시,시민봉사과,031-828-2466,2020-12-02\r\n가능동          ,26129 ,13051 ,13078 ,5.68,2.83,2.84,99.79,12432 ,2.1,의정부시,시민봉사과,031-828-2466,2020-12-02\r\n흥선동          ,19151 ,9656 ,9495 ,4.16,2.1,2.06,101.7,9295 ,2.06,의정부시,시민봉사과,031-828-2466,2020-12-02\r\n녹양동          ,22197 ,11078 ,11119 ,4.82,2.41,2.42,99.63,9503 ,2.34,의정부시,시민봉사과,031-828-2466,2020-12-02\r\n&#39;]</div>

# %%
_my = popRddBin.map(lambda x :x[1].decode('euc-kr'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
popRddBin = spark.sparkContext.binaryFiles(os.path.join("/FileStore/tables/data","경기도_의정부시_인구현황_20201202.csv"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
popDf = spark\
            .read.option("charset", "euc-kr")\
            .option("header", "true")\
            .csv(os.path.join("/FileStore/tables/data","경기도_의정부시_인구현황_20201202.csv"))

popDf.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------------+----------+----------+----------+----------+----------+----------+------+------+----------+----------+----------+------------+--------------+
#         행정기관|인구수(계)|인구수(남)|인구수(여)|구성비(계)|구성비(남)|구성비(여)|  성비|세대수|세대당인구|관리기관명|관리부서명|부서전화번호|데이터기준일자|
# +----------------+----------+----------+----------+----------+----------+----------+------+------+----------+----------+----------+------------+--------------+
# 의정부1동       |    31515 |    16078 |    15437 |      6.85|      3.49|      3.35|104.15|19338 |      1.63|  의정부시|시민봉사과|031-828-2466|    2020-12-02|
# 의정부2동       |    31239 |    15480 |    15759 |      6.79|      3.36|      3.42| 98.23|15879 |      1.97|  의정부시|시민봉사과|031-828-2466|    2020-12-02|
# 호원1동         |    36297 |    17703 |    18594 |      7.88|      3.85|      4.04| 95.21|15619 |      2.32|  의정부시|시민봉사과|031-828-2466|    2020-12-02|
# 호원2동         |    35314 |    17124 |    18190 |      7.67|      3.72|      3.95| 94.14|13598 |       2.6|  의정부시|시민봉사과|031-828-2466|    2020-12-02|
# 장암동          |    20728 |     9880 |    10848 |       4.5|      2.15|      2.36| 91.08| 8662 |      2.39|  의정부시|시민봉사과|031-828-2466|    2020-12-02|
# +----------------+----------+----------+----------+----------+----------+----------+------+------+----------+----------+----------+------------+--------------+
# only showing top 5 rows
#
# </div>

# %%
for i in popRdd.take(5):
    print(i)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">�������,�α���(��),�α���(��),�α���(��),������(��),������(��),������(��),����,�����,������α�,���������,�����μ���,�μ���ȭ��ȣ,�����ͱ�������
# ������1��       ,31515 ,16078 ,15437 ,6.85,3.49,3.35,104.15,19338 ,1.63,�����ν�,�ùκ����,031-828-2466,2020-12-02
# ������2��       ,31239 ,15480 ,15759 ,6.79,3.36,3.42,98.23,15879 ,1.97,�����ν�,�ùκ����,031-828-2466,2020-12-02
# ȣ��1��         ,36297 ,17703 ,18594 ,7.88,3.85,4.04,95.21,15619 ,2.32,�����ν�,�ùκ����,031-828-2466,2020-12-02
# ȣ��2��         ,35314 ,17124 ,18190 ,7.67,3.72,3.95,94.14,13598 ,2.6,�����ν�,�ùκ����,031-828-2466,2020-12-02
# </div>

# %%
popRdd.take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[71]: [&#39;�������,�α���(��),�α���(��),�α���(��),������(��),������(��),������(��),����,�����,������α�,���������,�����μ���,�μ���ȭ��ȣ,�����ͱ�������&#39;,
#  &#39;������1��       ,31515 ,16078 ,15437 ,6.85,3.49,3.35,104.15,19338 ,1.63,�����ν�,�ùκ����,031-828-2466,2020-12-02&#39;,
#  &#39;������2��       ,31239 ,15480 ,15759 ,6.79,3.36,3.42,98.23,15879 ,1.97,�����ν�,�ùκ����,031-828-2466,2020-12-02&#39;,
#  &#39;ȣ��1��         ,36297 ,17703 ,18594 ,7.88,3.85,4.04,95.21,15619 ,2.32,�����ν�,�ùκ����,031-828-2466,2020-12-02&#39;,
#  &#39;ȣ��2��         ,35314 ,17124 ,18190 ,7.67,3.72,3.95,94.14,13598 ,2.6,�����ν�,�ùκ����,031-828-2466,2020-12-02&#39;]</div>

# %%
popRdd = spark.sparkContext\
    .textFile(os.path.join("/FileStore/tables/data","경기도_의정부시_인구현황_20201202.csv"), use_unicode=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import os
import pyspark

# os.environ["PYSPARK_PYTHON"]="/usr/bin/python3"
# os.environ["PYSPARK_DRIVER_PYTHON"]="/usr/bin/python3"
myConf=pyspark.SparkConf()
spark = pyspark.sql.SparkSession\
    .builder\
    .master("local")\
    .appName("myApp")\
    .config(conf=myConf)\
    .getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
